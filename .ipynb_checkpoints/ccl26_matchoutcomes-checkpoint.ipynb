# %%
import pandas as pd

# ─────────────────────────────────────────────────────────────────────────────
# LOAD — the raw export has a known quirk: the header row has 15 column names
# but every data row has 16 fields (a trailing per-opportunity row-counter with
# no header). Default read_csv silently uses column 0 as the index to absorb
# the mismatch, which shifts EVERY column over by one. index_col=False forces
# pandas to keep the header alignment and drop the extra unnamed trailing field
# instead (which we don't need for reporting).
# ─────────────────────────────────────────────────────────────────────────────
placementhistory = pd.read_csv('CareerLaunch2026PlacementHistory.csv', index_col=False)

print("=== Shape & columns ===")
print(placementhistory.shape)
print(placementhistory.columns.tolist())

print("\n=== Dtypes (raw) ===")
print(placementhistory.dtypes)

# Clean up types
placementhistory['Changed Date'] = pd.to_datetime(placementhistory['Changed Date'], format='%m/%d/%Y')
placementhistory['Student Code'] = placementhistory['Student Code'].astype('Int64')  # nullable int, drops the ".0"

print("\n=== Opportunity Status value counts ===")
print(placementhistory['Opportunity Status'].value_counts())

print("\n=== Hub ('Group Name') value counts ===")
print(placementhistory['Group Name'].value_counts())

print("\n=== Placement Status value counts (raw log rows, NOT deduped) ===")
print(placementhistory['Placement Status'].value_counts())

print("\n=== Date range covered ===")
print(placementhistory['Changed Date'].min(), '->', placementhistory['Changed Date'].max())

print("\n=== Daily change volume (helps spot bulk-match days) ===")
print(placementhistory['Changed Date'].value_counts().sort_index())

# ─────────────────────────────────────────────────────────────────────────────
# This file is a STATUS LOG, not one row per placement. Many Opportunity /
# Student pairs show up multiple times as their status changes over time
# (e.g. Offered -> Confirmed, or Offered -> Rejected).
# ─────────────────────────────────────────────────────────────────────────────
matched = placementhistory.dropna(subset=['Student Code']).copy()
dupe_counts = matched.groupby(['Opportunity Id', 'Student Code']).size()
print(f"\n{(dupe_counts > 1).sum()} of {len(dupe_counts)} opportunity-student pairs have more than one log row")

# Take the LATEST status per opportunity-student pair (sort by date, keep last)
matched_sorted = matched.sort_values(['Opportunity Id', 'Student Code', 'Changed Date', 'Changed Time'])
latest_status = matched_sorted.groupby(['Opportunity Id', 'Student Code']).tail(1).copy()

print(f"\n=== Deduped to {len(latest_status)} unique opportunity-student final records ===")
print(latest_status['Placement Status'].value_counts())

confirmed = latest_status[latest_status['Placement Status'] == 'Confirmed'].copy()

# ─────────────────────────────────────────────────────────────────────────────
# ONE-STUDENT-ONE-PLACEMENT RULE — this program doesn't allow simultaneous
# placements. A handful of students (29 this cycle) show up Confirmed at more
# than one opportunity because an earlier placement was superseded by a later
# manual rematch. Keep only the most recent Confirmed record per student;
# earlier ones are dropped as superseded, not counted as separate placements.
# ─────────────────────────────────────────────────────────────────────────────
pre_deduped_count = len(confirmed)
confirmed = confirmed.sort_values(['Student Code', 'Changed Date', 'Changed Time'])
confirmed = confirmed.groupby('Student Code').tail(1).copy()

print(f"\n=== One-student-one-placement rule ===")
print(f"Confirmed records before dedup: {pre_deduped_count}")
print(f"Confirmed records after keeping latest per student: {len(confirmed)}")
print(f"Superseded (earlier, replaced) records dropped: {pre_deduped_count - len(confirmed)}")

# ─────────────────────────────────────────────────────────────────────────────
# CORE MATCHING FUNNEL (final status only)
# ─────────────────────────────────────────────────────────────────────────────
print("\n=== Final status by hub ===")
funnel = latest_status.groupby(['Group Name', 'Placement Status']).size().unstack(fill_value=0)
print(funnel)

print(f"\nTotal CONFIRMED placements: {len(confirmed)}")
print(f"Unique students confirmed: {confirmed['Student Code'].nunique()}")
print(f"Unique agencies matched:   {confirmed['Agency Id'].nunique()}")

print("\n=== Confirmed matches & unique agencies by hub ===")
by_hub = confirmed.groupby('Group Name').agg(
    students_matched=('Student Code', 'nunique'),
    agencies_matched=('Agency Id', 'nunique'),
    opportunities_used=('Opportunity Id', 'nunique'),
)
print(by_hub)

# ─────────────────────────────────────────────────────────────────────────────
# MATCH TYPE — per Elijah (program lead): there is no separate "bulk
# rematching" category. The rule is simple and mirrors last cycle exactly:
#   - Bulk Match: placements he personally processed (elijahnunez@gmail.com),
#     regardless of date.
#   - Pre-Match: anything confirmed before his bulk match run began.
#   - Manual Match: everything else, including the high-volume July 1-2 push
#     by central office staff (Allison Griffin / Jaquelyn Abo Trabi Al Awar)
#     that we'd previously (incorrectly) split out as its own "Round 2" bucket.
#
# Note this also corrects the Pre-Match cutoff: Elijah's own bulk-match rows
# actually start 6/9 (not 6/4, our earlier approximation), so 231 confirmed
# placements from 6/4-6/8 by other accounts now correctly fall under
# Pre-Match rather than Bulk Match.
# ─────────────────────────────────────────────────────────────────────────────
BULK_ACCOUNT = 'elijahnunez@gmail.com'
BULK_START_DATE = pd.Timestamp('2026-06-09')  # Elijah's own bulk match run began here

print("\n=== Created By value counts, top 15 (staff/bulk accounts vs. student/coordinator IDs) ===")
print(confirmed['Created By'].value_counts().head(15))


def classify_match_type(row):
    if BULK_ACCOUNT in row['Created By']:
        return 'Bulk Match'
    if row['Changed Date'] < BULK_START_DATE:
        return 'Pre-Match'
    return 'Manual Match'


confirmed['match_type'] = confirmed.apply(classify_match_type, axis=1)

print("\n=== Match type totals (overall) ===")
print(confirmed['match_type'].value_counts())

print("\n=== Match type by hub ===")
match_type_by_hub = confirmed.groupby(['Group Name', 'match_type']).size().unstack(fill_value=0)
print(match_type_by_hub)

print("\n=== Final summary table (mirrors last cycle's report format) ===")
summary = confirmed.groupby('Group Name').agg(
    Unique_Students_Matched=('Student Code', 'nunique'),
    Unique_Agencies_Matched=('Agency Id', 'nunique'),
).join(
    confirmed.pivot_table(index='Group Name', columns='match_type', values='Student Code',
                           aggfunc='nunique', fill_value=0)
)
print(summary)
print(f"\nTotal Unique Agencies Matched (all hubs): {confirmed['Agency Id'].nunique()}")

# ─────────────────────────────────────────────────────────────────────────────
# CAPACITY UTILIZATION — how full did opportunities get vs. their Min/Max Places?
# ─────────────────────────────────────────────────────────────────────────────
print("\n=== Capacity check ===")
opp_capacity = placementhistory[['Opportunity Id', 'Min Places', 'Max Places']].drop_duplicates('Opportunity Id')
opp_capacity['Max Places'] = pd.to_numeric(opp_capacity['Max Places'], errors='coerce')
filled = confirmed.groupby('Opportunity Id').size().rename('Filled')
capacity = opp_capacity.set_index('Opportunity Id').join(filled).fillna({'Filled': 0})
print(capacity.describe())

# ─────────────────────────────────────────────────────────────────────────────
# GEOGRAPHY — sanity check before mapping
# ─────────────────────────────────────────────────────────────────────────────
print("\n=== Missing lat/lon among confirmed placements ===")
print(confirmed[['Postal Address Latitude', 'Postal Address Longitude']].isna().sum())
# Out:
# === Shape & columns ===
# (3043, 15)
# ['Opportunity Id', 'Opportunity Name', 'Opportunity Status', 'Group Name', 'Min Places', 'Max Places', 'Agency Id', 'Agency Name', 'Postal Address Latitude', 'Postal Address Longitude', 'Student Code', 'Changed Date', 'Created By', 'Placement Status', 'Changed Time']
#
# === Dtypes (raw) ===
# Opportunity Id                  str
# Opportunity Name                str
# Opportunity Status              str
# Group Name                      str
# Min Places                    int64
# Max Places                    int64
# Agency Id                       str
# Agency Name                     str
# Postal Address Latitude     float64
# Postal Address Longitude    float64
# Student Code                float64
# Changed Date                    str
# Created By                      str
# Placement Status                str
# Changed Time                    str
# dtype: object
#
# === Opportunity Status value counts ===
# Opportunity Status
# Published    2984
# Draft          39
# Archived       20
# Name: count, dtype: int64
#
# === Hub ('Group Name') value counts ===
# Group Name
# 2026 Career Launch - STEM and Green                   874
# 2026 Career Launch - Community and Social Services    785
# 2026 Career Launch - Healthcare                       719
# 2026 Career Launch - Marketing and Communications     665
# Name: count, dtype: int64
#
# === Placement Status value counts (raw log rows, NOT deduped) ===
# Placement Status
# Confirmed           2313
# Offered              414
# Withdrawn-Agency     294
# Rejected              22
# Name: count, dtype: int64
#
# === Date range covered ===
# 2026-05-18 00:00:00 -> 2026-07-07 00:00:00
#
# === Daily change volume (helps spot bulk-match days) ===
# Changed Date
# 2026-05-18       4
# 2026-05-19       3
# 2026-05-20       3
# 2026-05-21       1
# 2026-05-22       2
# 2026-05-26       6
# 2026-05-27       1
# 2026-05-28      10
# 2026-05-29      20
# 2026-06-01      27
# 2026-06-02      18
# 2026-06-03      15
# 2026-06-04     171
# 2026-06-05      87
# 2026-06-08      99
# 2026-06-09    1106
# 2026-06-10      85
# 2026-06-11     389
# 2026-06-15      81
# 2026-06-16      86
# 2026-06-17      89
# 2026-06-18     109
# 2026-06-19       2
# 2026-06-22       7
# 2026-06-23       8
# 2026-06-24      28
# 2026-06-25      13
# 2026-06-29      36
# 2026-06-30      18
# 2026-07-01     415
# 2026-07-02      68
# 2026-07-06       7
# 2026-07-07      29
# Name: count, dtype: int64
#
# 365 of 1856 opportunity-student pairs have more than one log row
#
# === Deduped to 1856 unique opportunity-student final records ===
# Placement Status
# Confirmed    1846
# Rejected       10
# Name: count, dtype: int64
#
# === One-student-one-placement rule ===
# Confirmed records before dedup: 1846
# Confirmed records after keeping latest per student: 1816
# Superseded (earlier, replaced) records dropped: 30
#
# === Final status by hub ===
# Placement Status                                    Confirmed  Rejected
# Group Name
# 2026 Career Launch - Community and Social Services        445         0
# 2026 Career Launch - Healthcare                           497         8
# 2026 Career Launch - Marketing and Communications         458         2
# 2026 Career Launch - STEM and Green                       446         0
#
# Total CONFIRMED placements: 1816
# Unique students confirmed: 1816
# Unique agencies matched:   331
#
# === Confirmed matches & unique agencies by hub ===
#                                                     students_matched  \
# Group Name
# 2026 Career Launch - Community and Social Services               445
# 2026 Career Launch - Healthcare                                  468
# 2026 Career Launch - Marketing and Communications                457
# 2026 Career Launch - STEM and Green                              446
#
#                                                     agencies_matched  \
# Group Name
# 2026 Career Launch - Community and Social Services               116
# 2026 Career Launch - Healthcare                                   97
# 2026 Career Launch - Marketing and Communications                137
# 2026 Career Launch - STEM and Green                               78
#
#                                                     opportunities_used
# Group Name
# 2026 Career Launch - Community and Social Services                 213
# 2026 Career Launch - Healthcare                                    139
# 2026 Career Launch - Marketing and Communications                  212
# 2026 Career Launch - STEM and Green                                124
#
# === Created By value counts, top 15 (staff/bulk accounts vs. student/coordinator IDs) ===
# Created By
# elijahnunez@gmail.com                    947
# Allison.Griffin - Allison Griffin        235
# 23053377 - Jaquelyn Abo Trabi Al Awar    119
# 23121245                                  87
# 24055325                                  62
# 23951622                                  59
# 23649926                                  56
# 23242110                                  52
# 21011650                                  52
# 24266252                                  36
# 15284296                                  28
# 21002423                                  28
# 23653063                                  26
# 23095478                                  13
# 21008274                                   9
# Name: count, dtype: int64
#
# === Match type totals (overall) ===
# match_type
# Bulk Match      947
# Manual Match    562
# Pre-Match       307
# Name: count, dtype: int64
#
# === Match type by hub ===
# match_type                                          Bulk Match  Manual Match  \
# Group Name
# 2026 Career Launch - Community and Social Services         182           165
# 2026 Career Launch - Healthcare                            222           155
# 2026 Career Launch - Marketing and Communications          381            61
# 2026 Career Launch - STEM and Green                        162           181
#
# match_type                                          Pre-Match
# Group Name
# 2026 Career Launch - Community and Social Services         98
# 2026 Career Launch - Healthcare                            91
# 2026 Career Launch - Marketing and Communications          15
# 2026 Career Launch - STEM and Green                       103
#
# === Final summary table (mirrors last cycle's report format) ===
#                                                     Unique_Students_Matched  \
# Group Name
# 2026 Career Launch - Community and Social Services                      445
# 2026 Career Launch - Healthcare                                         468
# 2026 Career Launch - Marketing and Communications                       457
# 2026 Career Launch - STEM and Green                                     446
#
#                                                     Unique_Agencies_Matched  \
# Group Name
# 2026 Career Launch - Community and Social Services                      116
# 2026 Career Launch - Healthcare                                          97
# 2026 Career Launch - Marketing and Communications                       137
# 2026 Career Launch - STEM and Green                                      78
#
#                                                     Bulk Match  Manual Match  \
# Group Name
# 2026 Career Launch - Community and Social Services         182           165
# 2026 Career Launch - Healthcare                            222           155
# 2026 Career Launch - Marketing and Communications          381            61
# 2026 Career Launch - STEM and Green                        162           181
#
#                                                     Pre-Match
# Group Name
# 2026 Career Launch - Community and Social Services         98
# 2026 Career Launch - Healthcare                            91
# 2026 Career Launch - Marketing and Communications          15
# 2026 Career Launch - STEM and Green                       103
#
# Total Unique Agencies Matched (all hubs): 331
#
# === Capacity check ===
#        Min Places  Max Places      Filled
# count  722.000000  722.000000  722.000000
# mean     1.512465    3.080332    2.515235
# std      1.834478    3.130836    2.650814
# min      0.000000    1.000000    0.000000
# 25%      1.000000    1.000000    1.000000
# 50%      1.000000    2.000000    2.000000
# 75%      1.000000    4.000000    3.000000
# max     26.000000   30.000000   29.000000
#
# === Missing lat/lon among confirmed placements ===
# Postal Address Latitude     138
# Postal Address Longitude    138
# dtype: int64
# C:\Users\juanb\AppData\Local\Temp\ipykernel_4856\923248641.py:11: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   placementhistory = pd.read_csv('CareerLaunch2026PlacementHistory.csv', index_col=False)

# %%
import pandas as pd

# ─────────────────────────────────────────────────────────────────────────────
# LOAD — same header/data mismatch as the placement history file (7 header
# names, 8 fields per row due to a trailing per-student sequence counter).
# index_col=False keeps the real 7 columns aligned and drops the counter.
# ─────────────────────────────────────────────────────────────────────────────
apps = pd.read_csv('CL26StudentOpportunityApplications.csv', index_col=False)

print("=== Raw shape & columns ===")
print(apps.shape)
print(apps.columns.tolist())

# ─────────────────────────────────────────────────────────────────────────────
# SCOPE TO CL26 — the full/unfiltered export (pulled without a hub filter in
# InPlace) mixes in: other program years, other campaigns, and internal
# QA/test entries (e.g. Student Code "000000"/"11111111", comments like
# "Cultural Corps staff testing InPlace features. Disregard application.").
#
# Rather than pattern-matching junk directly (fragile), we scope to CL26 by
# keeping only rows whose Opportunity Id appears in this cycle's placement
# history -- that file is ground truth for "real CL26 2026 opportunity,
# any of the four hubs." Anything else is out of scope by definition.
# ─────────────────────────────────────────────────────────────────────────────
ph = pd.read_csv('CareerLaunch2026PlacementHistory.csv', index_col=False)
cl26_opportunities = ph[['Opportunity Id', 'Opportunity Name', 'Group Name', 'Agency Id', 'Agency Name']].drop_duplicates('Opportunity Id')

print(f"\nCL26 opportunities (ground truth, all 4 hubs): {cl26_opportunities['Opportunity Id'].nunique()}")
print(f"Applications rows before scoping: {len(apps)}")

apps_scoped = apps.merge(cl26_opportunities, on='Opportunity Id', how='inner')

print(f"Applications rows after scoping to CL26 opportunities: {len(apps_scoped)}")
print(f"Dropped as out-of-scope (other programs/years/test entries): {len(apps) - len(apps_scoped)}")

print("\n=== Scoped applications by hub ===")
print(apps_scoped['Group Name'].value_counts())

# ─────────────────────────────────────────────────────────────────────────────
# BACKSTOP FLAGS — junk that happens to share an Opportunity Id with a real
# CL26 opportunity wouldn't get caught by the scoping step above. Flag (don't
# silently drop) anything that still looks suspicious so it can be reviewed.
# ─────────────────────────────────────────────────────────────────────────────
JUNK_COMMENT_KEYWORDS = ['disregard application', 'will be withdrawn', 'staff testing inplace']
suspicious_comment = apps_scoped['Opportunity Application Comments'].str.lower().str.contains(
    '|'.join(JUNK_COMMENT_KEYWORDS), na=False
)

# Repeated-digit codes like 000000, 11111111 read as very low-entropy strings
student_code_str = apps_scoped['Student Code'].astype(str)
suspicious_code = student_code_str.str.match(r'^(\d)\1*$', na=False)

flagged = apps_scoped[suspicious_comment | suspicious_code]
print(f"\n=== Flagged for manual review (suspicious comment or repeated-digit code): {len(flagged)} rows ===")
if len(flagged):
    print(flagged[['Student Code', 'Opportunity Id', 'Opportunity Application Status', 'Opportunity Application Comments']].head(10))

apps_clean = apps_scoped[~(suspicious_comment | suspicious_code)].copy()
print(f"\nFinal clean, CL26-scoped applications: {len(apps_clean)}")

# ─────────────────────────────────────────────────────────────────────────────
# CORE METRICS ON THE CLEANED DATA
# ─────────────────────────────────────────────────────────────────────────────
print("\n=== Application status breakdown ===")
print(apps_clean['Opportunity Application Status'].value_counts())

print("\n=== Unique students who applied ===")
print(apps_clean['Student Code'].nunique())

print("\n=== Applications by hub ===")
print(apps_clean['Group Name'].value_counts())

print("\n=== Coordinator Preference Rank coverage ===")
print(f"{apps_clean['Coordinator Preference Rank'].notna().sum()} of {len(apps_clean)} rows have a coordinator rank")

# Students who applied vs. who ended up confirmed (needs placement history dedup)
matched = ph.dropna(subset=['Student Code']).copy()
matched['Changed Date'] = pd.to_datetime(matched['Changed Date'], format='%m/%d/%Y')
matched['Student Code'] = matched['Student Code'].astype('Int64')
matched_sorted = matched.sort_values(['Opportunity Id', 'Student Code', 'Changed Date', 'Changed Time'])
latest = matched_sorted.groupby(['Opportunity Id', 'Student Code']).tail(1)
confirmed = latest[latest['Placement Status'] == 'Confirmed'].copy()
confirmed = confirmed.sort_values(['Student Code', 'Changed Date', 'Changed Time']).groupby('Student Code').tail(1)
confirmed_students = set(confirmed['Student Code'].astype(int).unique())

apps_clean['Student Code'] = apps_clean['Student Code'].astype(int)
applicant_students = set(apps_clean['Student Code'].unique())

print(f"\n=== Applicant funnel ===")
print(f"Students who applied (clean, CL26-scoped): {len(applicant_students)}")
print(f"Of those, confirmed placement:             {len(applicant_students & confirmed_students)}")
print(f"Of those, NOT confirmed:                   {len(applicant_students - confirmed_students)}")

# Split the non-confirmed group: still pending ("Applied" only) vs resolved with no path forward
non_confirmed = apps_clean[apps_clean['Student Code'].isin(applicant_students - confirmed_students)]
status_by_student = non_confirmed.groupby('Student Code')['Opportunity Application Status'].apply(set)
still_pending = status_by_student[status_by_student.apply(lambda s: s == {'Applied'})]
resolved_no_placement = status_by_student[~status_by_student.index.isin(still_pending.index)]

print(f"\nNon-confirmed, still pending (Applied only, no resolution): {len(still_pending)}")
print(f"Non-confirmed, resolved with no placement (Declined/Unsuccessful mix): {len(resolved_no_placement)}")
# Out:
# === Raw shape & columns ===
# (170589, 7)
# ['Opportunity Application Id', 'Opportunity Id', 'Opportunity Application Comments', 'Student Code', 'StudentPreference', 'Coordinator Preference Rank', 'Opportunity Application Status']
#
# CL26 opportunities (ground truth, all 4 hubs): 722
# Applications rows before scoping: 170589
# Applications rows after scoping to CL26 opportunities: 24622
# Dropped as out-of-scope (other programs/years/test entries): 145967
#
# === Scoped applications by hub ===
# Group Name
# 2026 Career Launch - Marketing and Communications     7606
# 2026 Career Launch - STEM and Green                   6188
# 2026 Career Launch - Healthcare                       5710
# 2026 Career Launch - Community and Social Services    5118
# Name: count, dtype: int64
#
# === Flagged for manual review (suspicious comment or repeated-digit code): 0 rows ===
#
# Final clean, CL26-scoped applications: 24622
#
# === Application status breakdown ===
# Opportunity Application Status
# Student Declined    21054
# Placed               1806
# Applied              1242
# Unsuccessful          519
# Successful              1
# Name: count, dtype: int64
#
# === Unique students who applied ===
# 1940
#
# === Applications by hub ===
# Group Name
# 2026 Career Launch - Marketing and Communications     7606
# 2026 Career Launch - STEM and Green                   6188
# 2026 Career Launch - Healthcare                       5710
# 2026 Career Launch - Community and Social Services    5118
# Name: count, dtype: int64
#
# === Coordinator Preference Rank coverage ===
# 1396 of 24622 rows have a coordinator rank
#
# === Applicant funnel ===
# Students who applied (clean, CL26-scoped): 1940
# Of those, confirmed placement:             1816
# Of those, NOT confirmed:                   124
#
# Non-confirmed, still pending (Applied only, no resolution): 11
# Non-confirmed, resolved with no placement (Declined/Unsuccessful mix): 113
# C:\Users\juanb\AppData\Local\Temp\ipykernel_1448\988252876.py:8: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   apps = pd.read_csv('CL26StudentOpportunityApplications.csv', index_col=False)
# C:\Users\juanb\AppData\Local\Temp\ipykernel_1448\988252876.py:25: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   ph = pd.read_csv('CareerLaunch2026PlacementHistory.csv', index_col=False)

# %% [markdown]
# ## OLD

# %%
# Merge df with df_2 to get Agency Name, then count applications by hub + agency
agency_name_map = df_2[['Agency Id', 'Agency Name']].drop_duplicates()

apps_by_hub_agency = (
    df
    .merge(agency_name_map, on='Agency Id', how='left')
    .groupby(['Opportunity Campaign Name', 'Agency Name'])
    .size()
    .reset_index(name='Applications')
    .sort_values(['Opportunity Campaign Name', 'Applications'], ascending=[True, False])
)

# Show top 10 agencies per hub
top_agencies = apps_by_hub_agency.groupby('Opportunity Campaign Name').head(10)

for hub, group in top_agencies.groupby('Opportunity Campaign Name'):
    print(f"\n{'='*60}")
    print(f"  {hub}")
    print(f"{'='*60}")
    print(group[['Agency Name', 'Applications']].to_string(index=False))
# Out:
# ============================================================
#   2026 Spring Forward - Community and Social Services
# ============================================================
#                                                                   Agency Name  Applications
#                                                 Center for Justice Innovation           126
#                                                       Public Health Solutions           110
#                                                        Stand Out College Prep            87
#                                               Bridge Philanthropic Consulting            81
#                                                  YWCA of the City of New York            79
#                                   New York City Department of Social Services            69
#                                                     Catskill Animal Sanctuary            56
#                                                                 Girl Vow Inc.            56
#                                                        9/11 Memorial & Museum            53
# CUNY Office of Career and Internship Partnerships, Career Launch Program Team            53
#
# ============================================================
#   2026 Spring Forward - Healthcare
# ============================================================
#                              Agency Name  Applications
# NYC Health+Hospitals / Woodhull hospital           431
#      Endocrine Associates of West Villag           148
#                     Lenox Hill Radiology           112
#                                      YAI           107
#                         Essen Healthcare           106
#                  Adapt Community Network            99
#                Mount Sinai Health System            81
#                             York College            80
#                              PlayReadVIP            68
#             The Brooklyn Hospital Center            66
#
# ============================================================
#   2026 Spring Forward - Marketing and Communications
# ============================================================
#                                       Agency Name  Applications
#                                     Kazani Beauty           179
#                            The Difference App LLC           143
#                      Your Voice Entertainment LLC           122
#                  The New York Academy of Sciences           120
#                          Breuchkelen Eclectic LLC           115
#    Baruch College Starr Career Development Center           110
# News Ambassadors (Bridge Alliance Education Fund)            99
#                                     Front Row NYC            97
#                                World Cares Center            90
#                   Bridge Philanthropic Consulting            81
#
# ============================================================
#   2026 Spring Forward - STEM and Green
# ============================================================
#                                 Agency Name  Applications
#                       Evergreen Investments           219
#                      The Difference App LLC           205
# New York City Department of Social Services           170
#                                      Unadat           140
#                                  Sydra Inc.           115
#                              Blackfacts.com           112
#    Kapitus - Strategic Funding Source. Inc.            98
#                 Reach Into Cultural Heights            98
#                           Black to Business            90
#  New York City Department of Transportation            90

# %%
from tabulate import tabulate

# Merge df with df_2 to get Agency Name, then count applications by hub + agency
agency_name_map = df_2[['Agency Id', 'Agency Name']].drop_duplicates()

apps_by_hub_agency = (
    df
    .merge(agency_name_map, on='Agency Id', how='left')
    .groupby(['Opportunity Campaign Name', 'Agency Name'])
    .size()
    .reset_index(name='Applications')
    .sort_values(['Opportunity Campaign Name', 'Applications'], ascending=[True, False])
)

# Top 10 agencies per hub
top_agencies = (
    apps_by_hub_agency
    .groupby('Opportunity Campaign Name')
    .head(10)
    .rename(columns={'Opportunity Campaign Name': 'Hub'})
    .reset_index(drop=True)
)
top_agencies.index += 1

print(tabulate(top_agencies, headers='keys', tablefmt='simple', showindex=False))
# Out:
# Hub                                                  Agency Name                                                                      Applications
# ---------------------------------------------------  -----------------------------------------------------------------------------  --------------
# 2026 Spring Forward - Community and Social Services  Center for Justice Innovation                                                             126
# 2026 Spring Forward - Community and Social Services  Public Health Solutions                                                                   110
# 2026 Spring Forward - Community and Social Services  Stand Out College Prep                                                                     87
# 2026 Spring Forward - Community and Social Services  Bridge Philanthropic Consulting                                                            81
# 2026 Spring Forward - Community and Social Services  YWCA of the City of New York                                                               79
# 2026 Spring Forward - Community and Social Services  New York City Department of Social Services                                                69
# 2026 Spring Forward - Community and Social Services  Catskill Animal Sanctuary                                                                  56
# 2026 Spring Forward - Community and Social Services  Girl Vow Inc.                                                                              56
# 2026 Spring Forward - Community and Social Services  9/11 Memorial & Museum                                                                     53
# 2026 Spring Forward - Community and Social Services  CUNY Office of Career and Internship Partnerships, Career Launch Program Team              53
# 2026 Spring Forward - Healthcare                     NYC Health+Hospitals / Woodhull hospital                                                  431
# 2026 Spring Forward - Healthcare                     Endocrine Associates of West Villag                                                       148
# 2026 Spring Forward - Healthcare                     Lenox Hill Radiology                                                                      112
# 2026 Spring Forward - Healthcare                     YAI                                                                                       107
# 2026 Spring Forward - Healthcare                     Essen Healthcare                                                                          106
# 2026 Spring Forward - Healthcare                     Adapt Community Network                                                                    99
# 2026 Spring Forward - Healthcare                     Mount Sinai Health System                                                                  81
# 2026 Spring Forward - Healthcare                     York College                                                                               80
# 2026 Spring Forward - Healthcare                     PlayReadVIP                                                                                68
# 2026 Spring Forward - Healthcare                     The Brooklyn Hospital Center                                                               66
# 2026 Spring Forward - Marketing and Communications   Kazani Beauty                                                                             179
# 2026 Spring Forward - Marketing and Communications   The Difference App LLC                                                                    143
# 2026 Spring Forward - Marketing and Communications   Your Voice Entertainment LLC                                                              122
# 2026 Spring Forward - Marketing and Communications   The New York Academy of Sciences                                                          120
# 2026 Spring Forward - Marketing and Communications   Breuchkelen Eclectic LLC                                                                  115
# 2026 Spring Forward - Marketing and Communications   Baruch College Starr Career Development Center                                            110
# 2026 Spring Forward - Marketing and Communications   News Ambassadors (Bridge Alliance Education Fund)                                          99
# 2026 Spring Forward - Marketing and Communications   Front Row NYC                                                                              97
# 2026 Spring Forward - Marketing and Communications   World Cares Center                                                                         90
# 2026 Spring Forward - Marketing and Communications   Bridge Philanthropic Consulting                                                            81
# 2026 Spring Forward - STEM and Green                 Evergreen Investments                                                                     219
# 2026 Spring Forward - STEM and Green                 The Difference App LLC                                                                    205
# 2026 Spring Forward - STEM and Green                 New York City Department of Social Services                                               170
# 2026 Spring Forward - STEM and Green                 Unadat                                                                                    140
# 2026 Spring Forward - STEM and Green                 Sydra Inc.                                                                                115
# 2026 Spring Forward - STEM and Green                 Blackfacts.com                                                                            112
# 2026 Spring Forward - STEM and Green                 Kapitus - Strategic Funding Source. Inc.                                                   98
# 2026 Spring Forward - STEM and Green                 Reach Into Cultural Heights                                                                98
# 2026 Spring Forward - STEM and Green                 Black to Business                                                                          90
# 2026 Spring Forward - STEM and Green                 New York City Department of Transportation                                                 90
